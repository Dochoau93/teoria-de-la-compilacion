# %% [markdown]
# # Generación Automática de Código
# Notas de clase sobre Teoría de la Compilación

# %% [markdown]
# **Juan David Velásquez Henao**
# jdvelasq@unal.edu.co
# Universidad Nacional de Colombia, Sede Medellín
# Facultad de Minas
# Medellín, Colombia
#
# [Licencia](https://github.com/jdvelasq/teoria-de-la-compilacion/blob/master/LICENCIA.txt)
# [Readme](https://github.com/jdvelasq/teoria-de-la-compilacion/blob/master/readme.md)

# %% [markdown]
# **Software utilizado**.
#
# > Este es un documento interactivo escrito como un notebook de [Jupyter](http://jupyter.org), en el cual se presenta una introducción al diseño de lectores, generadores, traductores, interpretes y compiladores. Los notebooks de Jupyter permiten incoporar simultáneamente código, texto, gráficos y ecuaciones. El código presentado en este notebook puede ejecutarse en los sistemas operativos Windows, Linux y OS X.
#
# > Haga click [aquí](https://github.com/jdvelasq/guias-de-instalacion) para obtener instrucciones detalladas sobre como instalar Jupyter en Windows y Mac OS X.
#
# > Haga clic [aquí](http://nbviewer.jupyter.org/github/jdvelasq/teoria-de-la-compilacion/blob/master/01-introduccion.ipynb) para ver la última versión de este documento en nbviewer.
#
# > Descargue la última versión de este documento, los archivos de datos y los programas en Python a su disco duro; luego, carguelos y ejecutelos en línea en [Try Jupyter!](https://try.jupyter.org)

# %% [markdown]
# #### Contenido

# %% [markdown]
# > * [Técnicas de generación de código intermedio](#Técnicas-de-generación-de-código-intermedio)
#     * [Tipos de código](#Tipos-de-código)
#     * [Generación básica de código intermedio](#Generación-básica-de-código-intermedio)
#     * [Generación básica de código de 0 direcciones](#Generación-básica-de-código-de-0-direcciones)
#     * [Generación básica de código de 3 direcciones](#Generación-básica-de-código-de-3-direcciones)
#     * [Pseudocódigo para generación automática de código](#Pseudocódigo-para-generación-automática-de-código)
#     * [Generación de código destino](#Generación-de-código-destino)
# * [Generación de código de tres direcciones](#Generación-de-código-de-tres-direcciones)
#     * [Constantes y variables](#Constantes-y-variables)
#     * [Ejemplo 1](#Ejemplo-1)
#     * [Ejemplo 2](#Ejemplo-2)
# * [Implementación del generador de código para una máquina de registros](#Implementación-del-generador-de-código-para-una-máquina-de-registros)
# * [Implementación del generador de código para una máquina de stack](#Implementación-del-generador-de-código-para-una-máquina-de-stack)

# %% [markdown]
# # Técnicas de generación de código intermedio

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ## Tipos de código

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Expresión:
#      x = 1 + 2 + 3;
#
#
# Código de cero direcciones (similar al código de una máquina de 0 direcciones):
#
#      1
#      2
#      +
#      3
#      +
#      STO 1
#
# Código de tres direcciones (Similar al código de una máquina de 3 direcciones. Se asume que hay un número infinito de registros.):
#
#      ADD+ 1 0 1
#      ADD+ 2 0 2
#      +    1 1 2
#      ADD+ 2 0 3
#      +    1 1 2
#      STO  1 1

# %% [markdown]
# ## Generación básica de código intermedio

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ![alt text](images/tcc-10-1-genbasica.jpg)

# %% [markdown]
# ## Generación básica de código de 0 direcciones

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ![alt text](images/tcc-10-2-gen0dir.jpg)

# %% [markdown]
# ## Generación básica de código de 3 direcciones

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ![alt text](images/tcc-10-3-gen3dir.jpg)

# %% [markdown]
# ## Pseudocódigo para generación automática de código

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
#     cGen <- function(T)
#        {
#        if not is.null(T) do
#          {
#          generar código de preparación para hijo izquierdo de T
#          cGen(hijo izquierdo de T)
#          generar código de preparación para hijo derecho de T
#          cGen(hijo derecho de T)
#          generar código que implementa T
#          }
#       }

# %% [markdown]
# ## Generación de código destino

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# **Macro–expansión.**
# Reemplaza cada instrucción del código intermedio por código assembler.
#
# **Simulación estática.**
# Simulación del efecto del código intermedio y generación de código assembler que genere el mismo efecto.

# %% [markdown]
# ![alt text](images/tcc-10-4-genCodDest.jpg)

# %% [markdown]
# # Generación de código de tres direcciones

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ## Constantes y variables

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# **NUM**
#
#     ADD+  $reg 0 NUM
#
# <br>
#
# **ID**
#
#     RCL $reg ID
#
#
# **Asignación**
#
#     STO $reg ID
#
#
# ## FUNCIONES
#
# **`UFID`** ( *`arg1`*, *`arg2`*, ..., *`argN`*)
#
#     <Código para evaluar arg1, se asigna a memoria>
#     <Código para evaluar arg2, se asigna a memoria>
#     ...
#     <Código para evaluar argN, se asigna a memoria>
#     call UFID
#     <se recupera el valor retornado de memoria>
#
# <br>
#
# **`FUNCTION UFID`** ( *`arg1`*, *`arg2`*, ..., *`argN`*) *`stmt_block`*
#
#     <entry point de FID>
#     <cuerpo de la función>
#     <salva el valor retornado a memoria>
#
#
# ## EXPRESIONES LÓGICAS Y MATEMÁTICAS
#
# **`OP`**  *`arg`* (Expresiones con un único argumento)
#
#     <código para evaluar arg>
#     <instrucción para ejecutar op>
#
#
# *`arg1`* **`OP`** *`arg2`* (Expresiones con dos argumentos)
#
#     <código para evaluar arg1>
#     <código para evaluar arg2>
#     <instrucción para ejecutar op>
#
#
# ## ESTRUCTURAS CONDICIONALES
#
# **`WHEN`**  `(`  *`expr`* `)`  *`stmt_block`*
#
#
#         <Código antes del WHEN>
#         <Código para evaluar expr>
#         <salto condicional si FALSE a L1>
#         <Código para evaluar stmt_block>
#     L1:
#         <Código después del WHEN>
#
# <br>
#
# **`IF`**  `(` *`expr`* `)`  **`DO`** *`stmt_block`*  **`ELSE`**  *`stmt_block`*
#
#
#         <Código antes del IF>
#         <Código para evaluar expr>
#         <salto condicional si FALSE a L1>
#         <Código para evaluar then stmt_block>
#         <salto incondicional a L2>
#     L1:
#         <Código para evaluar ELSE stmt_block>
#     L2:
#         <Código después del IF>
#
#
# ## CICLOS
#
# **`WHILE`**  `(` *`expr`* `)`  *`stmt_block`*
#
#
#
#         <Código antes del WHILE>
#     L1:
#         <Código para evaluar expr>
#         <salto condicional si FALSE a L2>
#         <Código para evaluar stmt_block>
#         <salto incondicional a L1>
#     L2:
#         <Código después del WHILE>
#
# <br>
# **`LOOP`**  *`stmt_block`*
#
#
#         <Código antes del LOOP>
#     L1:
#         <Código para evaluar stmt_block>
#         <salto incondicional a L1>
#     L2:
#         <Código después del LOOP>
#
# <br>
# **`REPEAT NUM`** *`stmt_block`*
#
#         <Código antes del REPEAT>
#         <Crea la variable temporal t1>
#         <Hace t1 := NUM>
#     L1:
#         <Evalúa t1 == 0>
#         <salto condicional si FALSE a L2>
#         <Código para evaluar stmt_block>
#         <Hace t1 = t1 – 1>
#         <salto incondicional a L1>
#     L2:
#         <Código después del REPEAT>
#
#
# <br>
# **`FOR ID`** `:=` *`expr`*  **`TO`**  *`expr`* **`DO`** *`stmt_block`*
#
#
#         <Código antes del FOR>
#         <Código para evaluar expr inicial>
#         <Código para asignar ID>
#     L1:
#         <Código para evaluar ID == expr final>
#         <salto condicional si FALSE a L2>
#         <Código para ejecutar stmt_block>
#         <código para incrementar ID>
#         <salto incondicional a L1>
#     L2:
#         <Código después del FOR>
#
# <br>
# **`CONTINUE`**
# **`BREAK`**
#
# Son instrucciones jmp a L1 y L2 respectivamente.

# %% [markdown]
# ## Ejemplo 1

# %% [markdown]
# [Contenido](#Contenido)

# %%
# %%writefile example.txt
# var z:num;
# z := 0;
# while (z < 10) do
#   {
#   z := z + 1;
#   write '-->':  z;
#   }
# end
# Out:
# Overwriting example.txt

# %%
# %%sh
# python yylex.py example.txt
# python yyparse.py example.txt
# python yysymboltab.py example.txt
# python yytypecheck.py example.txt
# Out:
# +-- TOKENTABLE
#     +-- VAR {lexeme: var, lineno: 0}
#     +-- ID {lexeme: z, lineno: 0}
#     +-- : {lexeme: :, lineno: 0}
#     +-- DATATYPE {lexeme: num, lineno: 0}
#     +-- ; {lexeme: ;, lineno: 0}
#     +-- ID {lexeme: z, lineno: 1}
#     +-- := {lexeme: :=, lineno: 1}
#     +-- NUM {lexeme: 0, lineno: 1}
#     +-- ; {lexeme: ;, lineno: 1}
#     +-- WHILE {lexeme: while, lineno: 2}
#     +-- ( {lexeme: (, lineno: 2}
#     +-- ID {lexeme: z, lineno: 2}
#     +-- < {lexeme: <, lineno: 2}
#     +-- NUM {lexeme: 10, lineno: 2}
#     +-- ) {lexeme: ), lineno: 2}
#     +-- DO {lexeme: do, lineno: 2}
#     +-- { {lexeme: {, lineno: 3}
#     +-- ID {lexeme: z, lineno: 4}
#     +-- := {lexeme: :=, lineno: 4}
#     +-- ID {lexeme: z, lineno: 4}
#     +-- + {lexeme: +, lineno: 4}
#     +-- NUM {lexeme: 1, lineno: 4}
#     +-- ; {lexeme: ;, lineno: 4}
#     +-- WRITE {lexeme: write, lineno: 5}
#     +-- STR {lexeme: '-->', lineno: 5}
#     +-- : {lexeme: :, lineno: 5}
#     +-- ID {lexeme: z, lineno: 5}
#     +-- ; {lexeme: ;, lineno: 5}
#     +-- } {lexeme: }, lineno: 6}
#     +-- END {lexeme: end, lineno: 7}
#     +-- END {lexeme: end, lineno: 1}
# +-- SYNTAXTREE
#     +-- FUNCTIONDECL {lineno: 0}
#     +-- MAINPROG {lineno: 0}
#         +-- VAR {lineno: 0}
#         |   +-- ID {datatype: num, lineno: 0, scope: 0, value: z}
#         +-- ASSIGN {lineno: 1, scope: 0, value: z}
#         |   +-- NUM {datatype: num, lineno: 1, value: 0}
#         +-- WHILE {lineno: 2}
#         |   +-- < {datatype: bool, lineno: 2}
#         |   |   +-- ID {lineno: 2, scope: 0, value: z}
#         |   |   +-- NUM {datatype: num, lineno: 2, value: 10}
#         |   +-- BLOCK {lineno: 4}
#         |       +-- ASSIGN {lineno: 4, scope: 0, value: z}
#         |       |   +-- + {datatype: num, lineno: 4}
#         |       |       +-- ID {lineno: 4, scope: 0, value: z}
#         |       |       +-- NUM {datatype: num, lineno: 4, value: 1}
#         |       +-- WRITE {lineno: 5}
#         |           +-- STR {datatype: str, lineno: 5, value: '-->'}
#         |           +-- ID {lineno: 5, scope: 0, value: z}
#         +-- END {lineno: 7}
# +-- SYMBOLTABLE
#     +-- $chs {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- $abs {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- $sgn {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- z {datatype: num, kind: uvar, location: 0, scope: 0}
# +-- SYNTAXTREE
#     +-- FUNCTIONDECL {lineno: 0}
#     +-- MAINPROG {lineno: 0}
#         +-- VAR {lineno: 0}
#         |   +-- ID {datatype: num, lineno: 0, scope: 0, value: z}
#         +-- ASSIGN {lineno: 1, scope: 0, value: z}
#         |   +-- NUM {datatype: num, lineno: 1, value: 0}
#         +-- WHILE {lineno: 2}
#         |   +-- < {datatype: bool, lineno: 2}
#         |   |   +-- ID {datatype: num, lineno: 2, scope: 0, value: z}
#         |   |   +-- NUM {datatype: num, lineno: 2, value: 10}
#         |   +-- BLOCK {lineno: 4}
#         |       +-- ASSIGN {lineno: 4, scope: 0, value: z}
#         |       |   +-- + {datatype: num, lineno: 4}
#         |       |       +-- ID {datatype: num, lineno: 4, scope: 0, value: z}
#         |       |       +-- NUM {datatype: num, lineno: 4, value: 1}
#         |       +-- WRITE {lineno: 5}
#         |           +-- STR {datatype: str, lineno: 5, value: '-->'}
#         |           +-- ID {datatype: num, lineno: 5, scope: 0, value: z}
#         +-- END {lineno: 7}

# %%
# %%sh
# python yyrbm.py example.txt
# cat 'example.txt.rbm'
# Out:
# '-->'
# %%
#           ADD+    1   0   0
#           STO     1   0
# LBL 255
#           RCL     2   0
#           ADD+    3   0  10
#           <       1   2   3
#           IFZ     1 254
#           RCL     2   0
#           ADD+    3   0   1
#           +       1   2   3
#           STO     1   0
#           STR     0
#           RCL     1   0
#           PRN     1
#           GTO   255
# LBL 254
#           HLT

# %%
# %%sh
# python yysbm.py example.txt
# cat 'example.txt.sbm'
# Out:
# '-->'
# %%
#           0
#           STO     0
# LBL 255
#           RCL     0
#           10
#           <
#           IFZ   254
#           RCL     0
#           1
#           +
#           STO     0
#           STR     0
#           RCL     0
#           PRN
#           GTO   255
# LBL 254
#           HLT

# %% [markdown]
# ## Ejemplo 2

# %% [markdown]
# [Contenido](#Contenido)

# %%
# %%writefile example.txt
# ## funcion min(x, y)
# function @min:num (x:num, y:num)
#    {
#    when (x < y) do return x;
#    return y;
#    }
#
# ## funcion max(x, y)
# function @max:num (x:num, y:num)
#    {
#    if (x < y) do
#       {
#       return x;
#       }
#    else
#       {
#       return y;
#       }
#    }
#
# write 'min 1 -> ': @min(1,2);
# write 'max 2 -> ': @max(1,2);
#
# end
# Out:
# Overwriting example.txt

# %%
# %%sh
# python yylex.py example.txt
# python yyparse.py example.txt
# python yysymboltab.py example.txt
# python yytypecheck.py example.txt
# Out:
# +-- TOKENTABLE
#     +-- FUNCTION {lexeme: function, lineno: 1}
#     +-- UFID {lexeme: @min, lineno: 1}
#     +-- : {lexeme: :, lineno: 1}
#     +-- DATATYPE {lexeme: num, lineno: 1}
#     +-- ( {lexeme: (, lineno: 1}
#     +-- ID {lexeme: x, lineno: 1}
#     +-- : {lexeme: :, lineno: 1}
#     +-- DATATYPE {lexeme: num, lineno: 1}
#     +-- , {lexeme: ,, lineno: 1}
#     +-- ID {lexeme: y, lineno: 1}
#     +-- : {lexeme: :, lineno: 1}
#     +-- DATATYPE {lexeme: num, lineno: 1}
#     +-- ) {lexeme: ), lineno: 1}
#     +-- { {lexeme: {, lineno: 2}
#     +-- WHEN {lexeme: when, lineno: 3}
#     +-- ( {lexeme: (, lineno: 3}
#     +-- ID {lexeme: x, lineno: 3}
#     +-- < {lexeme: <, lineno: 3}
#     +-- ID {lexeme: y, lineno: 3}
#     +-- ) {lexeme: ), lineno: 3}
#     +-- DO {lexeme: do, lineno: 3}
#     +-- RETURN {lexeme: return, lineno: 3}
#     +-- ID {lexeme: x, lineno: 3}
#     +-- ; {lexeme: ;, lineno: 3}
#     +-- RETURN {lexeme: return, lineno: 4}
#     +-- ID {lexeme: y, lineno: 4}
#     +-- ; {lexeme: ;, lineno: 4}
#     +-- } {lexeme: }, lineno: 5}
#     +-- FUNCTION {lexeme: function, lineno: 8}
#     +-- UFID {lexeme: @max, lineno: 8}
#     +-- : {lexeme: :, lineno: 8}
#     +-- DATATYPE {lexeme: num, lineno: 8}
#     +-- ( {lexeme: (, lineno: 8}
#     +-- ID {lexeme: x, lineno: 8}
#     +-- : {lexeme: :, lineno: 8}
#     +-- DATATYPE {lexeme: num, lineno: 8}
#     +-- , {lexeme: ,, lineno: 8}
#     +-- ID {lexeme: y, lineno: 8}
#     +-- : {lexeme: :, lineno: 8}
#     +-- DATATYPE {lexeme: num, lineno: 8}
#     +-- ) {lexeme: ), lineno: 8}
#     +-- { {lexeme: {, lineno: 9}
#     +-- IF {lexeme: if, lineno: 10}
#     +-- ( {lexeme: (, lineno: 10}
#     +-- ID {lexeme: x, lineno: 10}
#     +-- < {lexeme: <, lineno: 10}
#     +-- ID {lexeme: y, lineno: 10}
#     +-- ) {lexeme: ), lineno: 10}
#     +-- DO {lexeme: do, lineno: 10}
#     +-- { {lexeme: {, lineno: 11}
#     +-- RETURN {lexeme: return, lineno: 12}
#     +-- ID {lexeme: x, lineno: 12}
#     +-- ; {lexeme: ;, lineno: 12}
#     +-- } {lexeme: }, lineno: 13}
#     +-- ELSE {lexeme: else, lineno: 14}
#     +-- { {lexeme: {, lineno: 15}
#     +-- RETURN {lexeme: return, lineno: 16}
#     +-- ID {lexeme: y, lineno: 16}
#     +-- ; {lexeme: ;, lineno: 16}
#     +-- } {lexeme: }, lineno: 17}
#     +-- } {lexeme: }, lineno: 18}
#     +-- WRITE {lexeme: write, lineno: 20}
#     +-- STR {lexeme: 'min 1 -> ', lineno: 20}
#     +-- : {lexeme: :, lineno: 20}
#     +-- UFID {lexeme: @min, lineno: 20}
#     +-- ( {lexeme: (, lineno: 20}
#     +-- NUM {lexeme: 1, lineno: 20}
#     +-- , {lexeme: ,, lineno: 20}
#     +-- NUM {lexeme: 2, lineno: 20}
#     +-- ) {lexeme: ), lineno: 20}
#     +-- ; {lexeme: ;, lineno: 20}
#     +-- WRITE {lexeme: write, lineno: 21}
#     +-- STR {lexeme: 'max 2 -> ', lineno: 21}
#     +-- : {lexeme: :, lineno: 21}
#     +-- UFID {lexeme: @max, lineno: 21}
#     +-- ( {lexeme: (, lineno: 21}
#     +-- NUM {lexeme: 1, lineno: 21}
#     +-- , {lexeme: ,, lineno: 21}
#     +-- NUM {lexeme: 2, lineno: 21}
#     +-- ) {lexeme: ), lineno: 21}
#     +-- ; {lexeme: ;, lineno: 21}
#     +-- END {lexeme: end, lineno: 23}
#     +-- END {lexeme: end, lineno: 1}
# +-- SYNTAXTREE
#     +-- FUNCTIONDECL {lineno: 1}
#     |   +-- FUNCTION {datatype: num, lineno: 1, scope: 1, value: @min}
#     |   |   +-- ARGS {lineno: 1}
#     |   |   |   +-- ID {datatype: num, lineno: 1, scope: 1, value: x}
#     |   |   |   +-- ID {datatype: num, lineno: 1, scope: 1, value: y}
#     |   |   +-- BLOCK {lineno: 3}
#     |   |       +-- WHEN {lineno: 3}
#     |   |       |   +-- < {datatype: bool, lineno: 3}
#     |   |       |   |   +-- ID {lineno: 3, scope: 1, value: x}
#     |   |       |   |   +-- ID {lineno: 3, scope: 1, value: y}
#     |   |       |   +-- RETURN {datatype: num, lineno: 3, scope: 1, value: __return__}
#     |   |       |       +-- ID {lineno: 3, scope: 1, value: x}
#     |   |       +-- RETURN {datatype: num, lineno: 4, scope: 1, value: __return__}
#     |   |           +-- ID {lineno: 4, scope: 1, value: y}
#     |   +-- FUNCTION {datatype: num, lineno: 8, scope: 2, value: @max}
#     |       +-- ARGS {lineno: 8}
#     |       |   +-- ID {datatype: num, lineno: 8, scope: 2, value: x}
#     |       |   +-- ID {datatype: num, lineno: 8, scope: 2, value: y}
#     |       +-- BLOCK {lineno: 10}
#     |           +-- IF {lineno: 10}
#     |               +-- < {datatype: bool, lineno: 10}
#     |               |   +-- ID {lineno: 10, scope: 2, value: x}
#     |               |   +-- ID {lineno: 10, scope: 2, value: y}
#     |               +-- BLOCK {lineno: 12}
#     |               |   +-- RETURN {datatype: num, lineno: 12, scope: 2, value: __return__}
#     |               |       +-- ID {lineno: 12, scope: 2, value: x}
#     |               +-- BLOCK {lineno: 16}
#     |                   +-- RETURN {datatype: num, lineno: 16, scope: 2, value: __return__}
#     |                       +-- ID {lineno: 16, scope: 2, value: y}
#     +-- MAINPROG {lineno: 20}
#         +-- WRITE {lineno: 20}
#         |   +-- STR {datatype: str, lineno: 20, value: 'min 1 -> '}
#         |   +-- UFCALL {lineno: 20, value: @min}
#         |       +-- NUM {datatype: num, lineno: 20, value: 1}
#         |       +-- NUM {datatype: num, lineno: 20, value: 2}
#         +-- WRITE {lineno: 21}
#         |   +-- STR {datatype: str, lineno: 21, value: 'max 2 -> '}
#         |   +-- UFCALL {lineno: 21, value: @max}
#         |       +-- NUM {datatype: num, lineno: 21, value: 1}
#         |       +-- NUM {datatype: num, lineno: 21, value: 2}
#         +-- END {lineno: 23}
# +-- SYMBOLTABLE
#     +-- $chs {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- $abs {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- $sgn {argstype: ['num'], datatype: num, kind: bfun, nargs: 1}
#     +-- @min {argstype: ['num', 'num'], datatype: num, entrylabel: 0, kind: ufun, nargs: 2, scope: 1}
#     +-- __return__ {datatype: num, kind: uvar, location: 0, scope: 1}
#     +-- x {datatype: num, kind: uvar, location: 1, scope: 1}
#     +-- y {datatype: num, kind: uvar, location: 2, scope: 1}
#     +-- @max {argstype: ['num', 'num'], datatype: num, entrylabel: 1, kind: ufun, nargs: 2, scope: 2}
#     +-- __return__ {datatype: num, kind: uvar, location: 3, scope: 2}
#     +-- x {datatype: num, kind: uvar, location: 4, scope: 2}
#     +-- y {datatype: num, kind: uvar, location: 5, scope: 2}
# +-- SYNTAXTREE
#     +-- FUNCTIONDECL {lineno: 1}
#     |   +-- FUNCTION {datatype: num, lineno: 1, scope: 1, value: @min}
#     |   |   +-- ARGS {lineno: 1}
#     |   |   |   +-- ID {datatype: num, lineno: 1, scope: 1, value: x}
#     |   |   |   +-- ID {datatype: num, lineno: 1, scope: 1, value: y}
#     |   |   +-- BLOCK {lineno: 3}
#     |   |       +-- WHEN {lineno: 3}
#     |   |       |   +-- < {datatype: bool, lineno: 3}
#     |   |       |   |   +-- ID {datatype: num, lineno: 3, scope: 1, value: x}
#     |   |       |   |   +-- ID {datatype: num, lineno: 3, scope: 1, value: y}
#     |   |       |   +-- RETURN {datatype: num, lineno: 3, scope: 1, value: __return__}
#     |   |       |       +-- ID {datatype: num, lineno: 3, scope: 1, value: x}
#     |   |       +-- RETURN {datatype: num, lineno: 4, scope: 1, value: __return__}
#     |   |           +-- ID {datatype: num, lineno: 4, scope: 1, value: y}
#     |   +-- FUNCTION {datatype: num, lineno: 8, scope: 2, value: @max}
#     |       +-- ARGS {lineno: 8}
#     |       |   +-- ID {datatype: num, lineno: 8, scope: 2, value: x}
#     |       |   +-- ID {datatype: num, lineno: 8, scope: 2, value: y}
#     |       +-- BLOCK {lineno: 10}
#     |           +-- IF {lineno: 10}
#     |               +-- < {datatype: bool, lineno: 10}
#     |               |   +-- ID {datatype: num, lineno: 10, scope: 2, value: x}
#     |               |   +-- ID {datatype: num, lineno: 10, scope: 2, value: y}
#     |               +-- BLOCK {lineno: 12}
#     |               |   +-- RETURN {datatype: num, lineno: 12, scope: 2, value: __return__}
#     |               |       +-- ID {datatype: num, lineno: 12, scope: 2, value: x}
#     |               +-- BLOCK {lineno: 16}
#     |                   +-- RETURN {datatype: num, lineno: 16, scope: 2, value: __return__}
#     |                       +-- ID {datatype: num, lineno: 16, scope: 2, value: y}
#     +-- MAINPROG {lineno: 20}
#         +-- WRITE {lineno: 20}
#         |   +-- STR {datatype: str, lineno: 20, value: 'min 1 -> '}
#         |   +-- UFCALL {datatype: num, lineno: 20, value: @min}
#         |       +-- NUM {datatype: num, lineno: 20, value: 1}
#         |       +-- NUM {datatype: num, lineno: 20, value: 2}
#         +-- WRITE {lineno: 21}
#         |   +-- STR {datatype: str, lineno: 21, value: 'max 2 -> '}
#         |   +-- UFCALL {datatype: num, lineno: 21, value: @max}
#         |       +-- NUM {datatype: num, lineno: 21, value: 1}
#         |       +-- NUM {datatype: num, lineno: 21, value: 2}
#         +-- END {lineno: 23}

# %%
# %%sh
# python yyrbm.py example.txt
# cat 'example.txt.rbm'
# Out:
# 'min 1 -> '
# 'max 2 -> '
# %%
#           GTO   255
# LBL 0
#           RCL     2   1
#           RCL     3   2
#           <       1   2   3
#           IFZ     1 254
#           RCL     1   1
#           STO     1   0
#           RET
# LBL 254
#           RCL     1   2
#           STO     1   0
#           RET
#           RET
# LBL 255
#           GTO   253
# LBL 1
#           RCL     2   4
#           RCL     3   5
#           <       1   2   3
#           IFZ     1 252
#           RCL     1   4
#           STO     1   3
#           RET
#           GTO   251
# LBL 252
#           RCL     1   5
#           STO     1   3
#           RET
# LBL 251
#           RET
# LBL 253
#           STR     0
#           ADD+    1   0   1
#           ADD+    2   0   2
#           STO     2   2
#           STO     1   1
#           GSB     0
#           RCL     1   0
#           PRN     1
#           STR     1
#           ADD+    1   0   1
#           ADD+    2   0   2
#           STO     2   5
#           STO     1   4
#           GSB     1
#           RCL     1   3
#           PRN     1
#           HLT

# %%
# %%sh
# python yysbm.py example.txt
# cat 'example.txt.sbm'
# Out:
# 'min 1 -> '
# 'max 2 -> '
# %%
#           GTO   255
# LBL 0
#           RCL     1
#           RCL     2
#           <
#           IFZ   254
#           RCL     1
#           STO     0
#           RET
# LBL 254
#           RCL     2
#           STO     0
#           RET
#           RET
# LBL 255
#           GTO   253
# LBL 1
#           RCL     4
#           RCL     5
#           <
#           IFZ   252
#           RCL     4
#           STO     3
#           RET
#           GTO   251
# LBL 252
#           RCL     5
#           STO     3
#           RET
# LBL 251
#           RET
# LBL 253
#           STR     0
#           1
#           2
#           STO     2
#           STO     1
#           GSB     0
#           RCL     0
#           PRN
#           STR     1
#           1
#           2
#           STO     5
#           STO     4
#           GSB     1
#           RCL     3
#           PRN
#           HLT

# %% [markdown]
# # Implementación del generador de código para una máquina de registros

# %% [markdown]
# [Contenido](#Contenido)

# %%
# %%sh
# pygmentize -O linenos=1 -g rbm.py
# Out:
# 0001: ###< 2016-08-28 18:12:00.911927 >###
# 0002:
# 0003: #
# 0004: #  rbm.py
# 0005: #    maquina virtual de registros
# 0006: #
# 0007:
# 0008: import shlex, sys, math
# 0009:
# 0010:
# 0011: def rbm(filename):
# 0012:     #
# 0013:     # registros del procesador
# 0014:     #
# 0015:     DR  = [0]    * 256   # Data Registers
# 0016:     TR  = [0]    * 256   # Temporary Registers
# 0017:     JT  = [None] * 256   # Jump Table
# 0018:     SF  = []             # Stack Frame
# 0019:     SS  = []             # Stack
# 0020:     LP  = []             # Literal Pool
# 0021:     IP  = 0              # Instruction Pointer
# 0022:     HLT = False          # HaLT register
# 0023:     CS  = ''             # Code Segment
# 0024:
# 0025:
# 0026:     #
# 0027:     # Carga del programa desde el archivo y lo separa en cadenas de texto
# 0028:     #
# 0029:     x = open(filename, 'r').readlines()
# 0030:     for n, line in enumerate(x):
# 0031:         if line[-1] == '\n':
# 0032:             line = line[:-1]
# 0033:         if line == '%%':
# 0034:             break
# 0035:         LP.append(line)
# 0036:
# 0037:     x = x[n+1:]
# 0038:
# 0039:     x = ''.join(x)
# 0040:     x = list(shlex.shlex(x))
# 0041:
# 0042:     #
# 0043:     # shlex separa la cadena '123.456' como '123', '.', '456'
# 0044:     # y debe unirse como un numero. La cadena de texto debe
# 0045:     # convertirse en numero
# 0046:     #
# 0047:     m = []
# 0048:     n = 0
# 0049:     while n < len(x):
# 0050:
# 0051:         if x[n] == 'RCL' and x[n+1] in ('+', '-', '*', '/', '%'):
# 0052:             m.append('RCL' + x[n+1])
# 0053:             n += 2
# 0054:
# 0055:         elif x[n] == 'STO' and x[n+1] == '+' and x[n+2] == '+':
# 0056:             m.append('STO++')
# 0057:             n += 3
# 0058:
# 0059:         elif x[n] == 'STO' and x[n+1] == '-' and x[n+2] == '-':
# 0060:             m.append('STO--')
# 0061:             n += 3
# 0062:
# 0063:         elif x[n] == 'STO' and x[n+1] in ('+', '-', '*', '/', '%'):
# 0064:             m.append('STO' + x[n+1])
# 0065:             n += 2
# 0066:
# 0067:         elif x[n] == 'ADD' and x[n+1] == '+':
# 0068:             m.append('ADD+')
# 0069:             n += 2
# 0070:
# 0071:         elif x[n] == '<' and x[n+1] == '=':
# 0072:             m.append('<=')
# 0073:             n += 2
# 0074:
# 0075:         elif x[n] == '>' and x[n+1] == '=':
# 0076:             m.append('>=')
# 0077:             n += 2
# 0078:
# 0079:         elif x[n] == '=' and x[n+1] == '=':
# 0080:             m.append('==')
# 0081:             n += 2
# 0082:
# 0083:         elif x[n] == '!' and x[n+1] == '=':
# 0084:             m.append('!=')
# 0085:             n += 2
# 0086:
# 0087:         elif len(m) >= 3 and m[-3] == 'ADD+':
# 0088:
# 0089:             if x[n] == '.':
# 0090:                 txt = '.' + x[n+1]
# 0091:                 m[-1] = float(txt)
# 0092:                 n += 2
# 0093:
# 0094:             elif x[n] == '-' and x[n+1].isdigit() and x[n+2] != '.':
# 0095:                 m.append(-int(x[n+1]))
# 0096:                 n += 2
# 0097:
# 0098:             elif x[n] == '-' and x[n+1].isdigit() and x[n+2] == '.' and not x[n+3]:
# 0099:                 txt = '-' + x[n+1] + '.'
# 0100:                 m.append(-float(txt))
# 0101:                 n += 3
# 0102:
# 0103:             elif x[n] == '-' and x[n+1].isdigit() and x[n+2] == '.' and x[n+3].isdigit():
# 0104:                 txt = '-' + x[n+1] + '.' + x[n+3]
# 0105:                 m.append(-float(txt))
# 0106:                 n += 4
# 0107:
# 0108:             elif x[n].isdigit() and x[n+1] == '.' and not x[n+2].isdigit():
# 0109:                 txt = x[n] + '.'
# 0110:                 m.append(float(txt))
# 0111:                 n += 2
# 0112:
# 0113:             elif x[n].isdigit() and x[n+1] == '.' and x[n+2].isdigit():
# 0114:                 txt = x[n] + '.' + x[n+2]
# 0115:                 m.append(float(txt))
# 0116:                 n += 3
# 0117:
# 0118:             else:
# 0119:                 m.append(int(x[n]))
# 0120:                 n += 1
# 0121:
# 0122:         elif x[n].isdigit():
# 0123:             m.append(int(x[n]))
# 0124:             n += 1
# 0125:
# 0126:         else:
# 0127:             m.append(x[n])
# 0128:             n += 1
# 0129:
# 0130:     CS = m
# 0131:
# 0132:     #
# 0133:     # Se actualiza la tabla de saltos (JT) con las
# 0134:     # posiciones de las etiquetas 'lbl' dentro del codigo.
# 0135:     # CS[i+1] es el numero de la etiqueta
# 0136:     # i es el numero de la instruccion dentro del programa
# 0137:     #
# 0138:     for i, code in enumerate(CS):
# 0139:
# 0140:         if CS[i] == 'LBL':
# 0141:             JT[CS[i+1]] = i
# 0142:
# 0143:     #
# 0144:     # Ejecucion del programa
# 0145:     #
# 0146:     while HLT != True and IP < len(CS):
# 0147:
# 0148:         #
# 0149:         # lee los argumentos de la instruccion
# 0150:         #
# 0151:         r = CS[IP+1] if IP+1 < len(CS) else []
# 0152:         s = CS[IP+2] if IP+2 < len(CS) else []
# 0153:         t = CS[IP+3] if IP+3 < len(CS) else []
# 0154:
# 0155:         # print(CS[IP], r, s, t)
# 0156:         # ---------------------------------------------------------------------
# 0157:         #
# 0158:         # parada del programa
# 0159:         #
# 0160:         if CS[IP] == 'HLT':
# 0161:
# 0162:             HLT = True
# 0163:
# 0164:         # ---------------------------------------------------------------------
# 0165:         #
# 0166:         # entrada / salida
# 0167:         #
# 0168:         elif CS[IP] == '?':
# 0169:
# 0170:             x = input()
# 0171:             a = int(x)
# 0172:             b = float(x)
# 0173:             if a == b:
# 0174:                 TR[r] = a
# 0175:             else:
# 0176:                 TR[r] = b
# 0177:             IP += 1
# 0178:
# 0179:         elif CS[IP] == 'PRN':
# 0180:
# 0181:             result = TR[r]
# 0182:             print(result)
# 0183:             IP += 1
# 0184:
# 0185:         elif CS[IP] == 'PRB':
# 0186:
# 0187:             result = TR[r]
# 0188:             if result == 0:
# 0189:                 print('false')
# 0190:             else:
# 0191:                 print('true')
# 0192:             IP += 1
# 0193:
# 0194:         elif CS[IP] == 'STR':
# 0195:
# 0196:             print(LP[r][1:-1], end = '')
# 0197:             IP += 1
# 0198:
# 0199:         elif CS[IP] == 'XCHG':
# 0200:
# 0201:             temp = TR[r]
# 0202:             TR[r] = TR[s]
# 0203:             TR[s] = temp
# 0204:
# 0205:         # ---------------------------------------------------------------------
# 0206:         #
# 0207:         # saltos / subrutinas
# 0208:         #
# 0209:
# 0210:         elif CS[IP] == 'LBL':
# 0211:
# 0212:             IP += 1
# 0213:
# 0214:         elif CS[IP] == 'GTO':
# 0215:
# 0216:             IP = JT[r] - 1
# 0217:
# 0218:         elif CS[IP] == 'IFZ':
# 0219:
# 0220:             IP = JT[s] - 1 if TR[r] == 0 else IP + 2
# 0221:
# 0222:         elif CS[IP] == 'IFNZ':
# 0223:
# 0224:             IP = JT[s] - 1 if TR[r] != 0 else IP + 2
# 0225:
# 0226:         elif CS[IP] == 'GSB':
# 0227:
# 0228:             SF.append(IP + 1)
# 0229:             IP = JT[r] - 1
# 0230:
# 0231:             for n in TR:
# 0232:                 SS.append(n)
# 0233:
# 0234:         elif CS[IP] == 'RET':
# 0235:
# 0236:             IP = SF.pop()
# 0237:
# 0238:             for n in range(len(TR)-1,-1,-1):
# 0239:                 TR[n] = SS.pop()
# 0240:
# 0241:         # ---------------------------------------------------------------------
# 0242:         #
# 0243:         # gestion de la memoria
# 0244:         #
# 0245:         elif CS[IP] == 'RCL':
# 0246:
# 0247:             TR[r] = DR[s]
# 0248:             IP += 2
# 0249:
# 0250:         elif CS[IP] == 'RCL+':
# 0251:
# 0252:             TR[r] += DR[s]
# 0253:             IP += 2
# 0254:
# 0255:         elif CS[IP] == 'RCL*':
# 0256:             IP += 2
# 0257:
# 0258:             TR[r] *= DR[s]
# 0259:
# 0260:         elif CS[IP] == 'RCL-':
# 0261:
# 0262:             TR[r] -= DR[s]
# 0263:             IP += 2
# 0264:
# 0265:         elif CS[IP] == 'RCL/':
# 0266:
# 0267:             TR[r] /= DR[s]
# 0268:             IP += 2
# 0269:
# 0270:         elif CS[IP] == 'RCL%':
# 0271:
# 0272:             TR[r] %= DR[s]
# 0273:             IP += 2
# 0274:
# 0275:         elif CS[IP] == 'STO':
# 0276:
# 0277:             DR[s] = TR[r]
# 0278:             IP += 2
# 0279:
# 0280:         elif CS[IP] == 'STO+':
# 0281:
# 0282:             DR[s] += TR[r]
# 0283:             IP += 2
# 0284:
# 0285:         elif CS[IP] == 'STO*':
# 0286:
# 0287:             DR[s] *= TR[r]
# 0288:             IP += 2
# 0289:
# 0290:         elif CS[IP] == 'STO-':
# 0291:
# 0292:             DR[s] -= TR[r]
# 0293:             IP += 2
# 0294:
# 0295:         elif CS[IP] == 'STO/':
# 0296:
# 0297:             DR[s] /= TR[r]
# 0298:             IP += 2
# 0299:
# 0300:         elif CS[IP] == 'STO%':
# 0301:
# 0302:             DR[s] %= TR[r]
# 0303:             IP += 2
# 0304:
# 0305:         elif CS[IP] == 'STO++':
# 0306:
# 0307:             DR[r] += 1
# 0308:             IP += 1
# 0309:
# 0310:         elif CS[IP] == 'STO--':
# 0311:
# 0312:             DR[r] -= 1
# 0313:             IP += 1
# 0314:
# 0315:         # ---------------------------------------------------------------------
# 0316:         #
# 0317:         # funciones matematicas (math library)
# 0318:         #
# 0319:         elif CS[IP] == 'SGN':
# 0320:
# 0321:             if TR[s] > 0:
# 0322:                 TR[r] = 1
# 0323:             elif TR[s] < 0:
# 0324:                 TR[r] = -1
# 0325:             else:
# 0326:                 TR[r] = 0
# 0327:             IP += 2
# 0328:
# 0329:         elif CS[IP] == 'FABS':
# 0330:
# 0331:             TR[r] = math.fabs(TR[s])
# 0332:             IP += 2
# 0333:
# 0334:         elif CS[IP] == 'SQRT':
# 0335:
# 0336:             TR[r] = math.sqrt(TR[s])
# 0337:             IP += 2
# 0338:
# 0339:         elif CS[IP] == 'LOG':
# 0340:
# 0341:             TR[r] = math.log(TR[s])
# 0342:             IP += 2
# 0343:
# 0344:         elif CS[IP] == 'EXP':
# 0345:
# 0346:             TR[r] = math.exp(TR[s])
# 0347:             IP += 2
# 0348:
# 0349:         elif CS[IP] == 'LOG10':
# 0350:
# 0351:             TR[r] = math.log10(TR[s])
# 0352:             IP += 2
# 0353:
# 0354:         elif CS[IP] == 'SIN':
# 0355:
# 0356:             TR[r] = math.sin(TR[s])
# 0357:             IP += 2
# 0358:
# 0359:         elif CS[IP] == 'COS':
# 0360:
# 0361:             TR[r] = math.cos(OS[s])
# 0362:             IP += 2
# 0363:
# 0364:         elif CS[IP] == 'TAN':
# 0365:
# 0366:             TR[r] = math.tan(TR[s])
# 0367:             IP += 2
# 0368:
# 0369:         elif CS[IP] == 'ASN':
# 0370:
# 0371:             TR[r] = math.asin(TR[s])
# 0372:             IP += 2
# 0373:
# 0374:         elif CS[IP] == 'ACS':
# 0375:
# 0376:             TR[r] = math.acos(TR[s])
# 0377:             IP += 2
# 0378:
# 0379:         elif CS[IP] == 'ATN':
# 0380:
# 0381:             TR[r] = math.atan(TR[s])
# 0382:             IP += 2
# 0383:         #
# 0384:         # funciones compelentarias
# 0385:         #
# 0386:         elif CS[IP] == 'CHS':
# 0387:
# 0388:             TR[r] = - TR[s]
# 0389:             IP += 2
# 0390:
# 0391:         elif CS[IP] == 'SQR':
# 0392:
# 0393:             TR[r] = TR[s] ^ 2
# 0394:             IP += 2
# 0395:
# 0396:         elif CS[IP] == 'INV':
# 0397:
# 0398:             TR[r] = 1 / TR[s]
# 0399:             IP += 2
# 0400:
# 0401:         elif CS[IP] == 'INTG':
# 0402:
# 0403:             TR[r] = int(TR[s])
# 0404:             IP += 2
# 0405:
# 0406:         elif CS[IP] == 'FRAC':
# 0407:
# 0408:             TR[r] = TR[s] - int(TR[s])
# 0409:             IP += 2
# 0410:
# 0411:         elif CS[IP] == 'ADD+':
# 0412:
# 0413:             TR[r] = TR[s] + t
# 0414:             IP += 3
# 0415:
# 0416:         elif CS[IP] == '+':
# 0417:
# 0418:             TR[r] = TR[s] + TR[t]
# 0419:             IP += 3
# 0420:
# 0421:         elif CS[IP] == '-':
# 0422:
# 0423:             TR[r] = TR[s] - TR[t]
# 0424:             IP += 3
# 0425:
# 0426:         elif CS[IP] == '*':
# 0427:
# 0428:             TR[r] = TR[s] * TR[t]
# 0429:             IP += 3
# 0430:
# 0431:         elif CS[IP] == '/':
# 0432:
# 0433:             TR[r] = TR[s] / TR[t]
# 0434:             IP += 3
# 0435:
# 0436:         elif CS[IP] == '%':
# 0437:
# 0438:             TR[r] = TR[s] % TR[t]
# 0439:             IP += 3
# 0440:
# 0441:         elif CS[IP] == '<':
# 0442:
# 0443:             TR[r] = 1 if TR[s] < TR[t] else 0
# 0444:             IP += 3
# 0445:
# 0446:         elif CS[IP] == '<=':
# 0447:
# 0448:             TR[r] = 1 if TR[s] <= TR[t] else 0
# 0449:             IP += 3
# 0450:
# 0451:         elif CS[IP] == '>':
# 0452:
# 0453:             TR[r] = 1 if TR[s] > TR[t] else 0
# 0454:             IP += 3
# 0455:
# 0456:         elif CS[IP] == '>=':
# 0457:
# 0458:             TR[r] = 1 if TR[s] >= TR[t] else 0
# 0459:             IP += 3
# 0460:
# 0461:         elif CS[IP] == '==':
# 0462:
# 0463:             TR[r] = 1 if TR[s] == TR[t] else 0
# 0464:             IP += 3
# 0465:
# 0466:         elif CS[IP] == '!=':
# 0467:
# 0468:             TR[r] = 1 if TR[s] != TR[t] else 0
# 0469:             IP += 3
# 0470:
# 0471:         elif CS[IP] == 'AND':
# 0472:
# 0473:             TR[r] = 1 if TR[s] and TR[t] else 0
# 0474:             IP += 3
# 0475:
# 0476:         elif CS[IP] == 'OR':
# 0477:
# 0478:             TR[r] = 1 if TR[s] or TR[t] else 0
# 0479:             IP += 3
# 0480:
# 0481:         elif CS[IP] == 'NOT':
# 0482:
# 0483:             TR[r] = 0 if TR[s] else 1
# 0484:             IP += 2
# 0485:
# 0486:         else:
# 0487:
# 0488:             txt = '\n\nrbm: Syntax error: unknown bytecode <{}>\n\n'.format(CS[IP])
# 0489:             print(txt)
# 0490:             sys.exit()
# 0491:
# 0492:         # ---------------------------------------------------------------------
# 0493:         TR[0] = 0   # TR[0] es siempre 0
# 0494:         IP += 1
# 0495:
# 0496:
# 0497:
# 0498: if __name__ == '__main__':
# 0499:
# 0500:
# 0501:     if len(sys.argv) > 1:
# 0502:         for filename in sys.argv[1:]:
# 0503:             rbm(filename)
# 0504:     else:
# 0505:         filename = input()
# 0506:         rbm(filename)
# 0507:

# %% [markdown]
# # Implementación del generador de código para una máquina de stack

# %% [markdown]
# [Contenido](#Contenido)

# %%
# %%sh
# pygmentize -O linenos=1 -g sbm.py
# Out:
# 0001: ###< 2016-08-28 18:12:00.913367 >###
# 0002:
# 0003: #! /usr/bin/python3
# 0004: import shlex, sys, math
# 0005:
# 0006:
# 0007: def sbm(filename):
# 0008:     #
# 0009:     # registros del procesador
# 0010:     #
# 0011:     OS  = []             # Operand Stack
# 0012:     DR  = [0]    * 256   # Data Registers
# 0013:     JT  = [None] * 256   # Jump Table
# 0014:     SF  = []             # Stack Frame
# 0015:     LP  = []             # Literal Pool
# 0016:     IP  = 0              # Instruction Pointer
# 0017:     HLT = False          # HaLT register
# 0018:     CS  = ''             # Code Segment
# 0019:
# 0020:
# 0021:
# 0022:     #
# 0023:     # Carga del programa desde el archivo y lo separa en cadenas de texto
# 0024:     #
# 0025:     x = open(filename, 'r').readlines()
# 0026:     for n, line in enumerate(x):
# 0027:         if line[-1] == '\n':
# 0028:             line = line[:-1]
# 0029:         if line == '%%':
# 0030:             break
# 0031:         LP.append(line)
# 0032:
# 0033:     x = x[n+1:]
# 0034:
# 0035:     x = ''.join(x)
# 0036:     x = list(shlex.shlex(x))
# 0037:
# 0038:     #
# 0039:     # shlex separa la cadena '123.456' como '123', '.', '456'
# 0040:     # y debe unirse como un numero. La cadena de texto debe
# 0041:     # convertirse en numero
# 0042:     #
# 0043:     m = []
# 0044:     n = 0
# 0045:     while n < len(x):
# 0046:
# 0047:         if x[n] == 'RCL' and x[n+1] in ('+', '-', '*', '/', '%'):
# 0048:             m.append('RCL' + x[n+1])
# 0049:             n += 2
# 0050:
# 0051:         elif x[n] == 'STO' and x[n+1] == '+' and x[n+2] == '+':
# 0052:             m.append('STO++')
# 0053:             n += 3
# 0054:
# 0055:         elif x[n] == 'STO' and x[n+1] == '-' and x[n+2] == '-':
# 0056:             m.append('STO--')
# 0057:             n += 3
# 0058:
# 0059:         elif x[n] == 'STO' and x[n+1] in ('+', '-', '*', '/', '%'):
# 0060:             m.append('STO' + x[n+1])
# 0061:             n += 2
# 0062:
# 0063:         elif x[n] == 'ADD' and x[n+1] == '+':
# 0064:             m.append('ADD+')
# 0065:             n += 2
# 0066:
# 0067:         elif x[n] == '<' and x[n+1] == '=':
# 0068:             m.append('<=')
# 0069:             n += 2
# 0070:
# 0071:         elif x[n] == '>' and x[n+1] == '=':
# 0072:             m.append('>=')
# 0073:             n += 2
# 0074:
# 0075:         elif x[n] == '=' and x[n+1] == '=':
# 0076:             m.append('==')
# 0077:             n += 2
# 0078:
# 0079:         elif x[n] == '!' and x[n+1] == '=':
# 0080:             m.append('!=')
# 0081:             n += 2
# 0082:
# 0083:         elif x[n].isdigit() and x[n+1] == '.' and not x[n+2].isdigit():
# 0084:             txt = x[n] + '.'
# 0085:             m.append(float(txt))
# 0086:             n += 2
# 0087:
# 0088:         elif x[n].isdigit() and x[n+1] == '.' and x[n+2].isdigit():
# 0089:             txt = x[n] + '.' + x[n+2]
# 0090:             m.append(float(txt))
# 0091:             n += 3
# 0092:
# 0093:         elif x[n].isdigit():
# 0094:             m.append(int(x[n]))
# 0095:             n += 1
# 0096:
# 0097:         else:
# 0098:             m.append(x[n])
# 0099:             n += 1
# 0100:
# 0101:     CS = m
# 0102:
# 0103:     #
# 0104:     # Se actualiza la tabla de saltos (JT) con las
# 0105:     # posiciones de las etiquetas 'lbl' dentro del codigo.
# 0106:     # CS[i+1] es el numero de la etiqueta
# 0107:     # i es el numero de la instruccion dentro del programa
# 0108:     #
# 0109:     for i, code in enumerate(CS):
# 0110:
# 0111:         if CS[i] == 'LBL':
# 0112:             JT[CS[i+1]] = i
# 0113:
# 0114:     #
# 0115:     # Ejecucion del programa
# 0116:     #
# 0117:     while HLT != True and IP < len(CS):
# 0118:
# 0119:         #
# 0120:         # lee los argumentos de la instruccion
# 0121:         #
# 0122:         r = CS[IP+1] if IP+1 < len(CS) else []
# 0123:
# 0124:         # ---------------------------------------------------------------------
# 0125:         #
# 0126:         # parada del programa
# 0127:         #
# 0128:         if CS[IP] == 'HLT':
# 0129:
# 0130:             HLT = True
# 0131:
# 0132:         # ---------------------------------------------------------------------
# 0133:         #
# 0134:         # entrada / salida
# 0135:         #
# 0136:         elif type(CS[IP]) == type(0) or type(CS[IP]) == type(0.0):
# 0137:
# 0138:             OS.append(CS[IP])
# 0139:
# 0140:         elif CS[IP] == '?':
# 0141:
# 0142:             x = input()
# 0143:             a = int(x)
# 0144:             b = float(x)
# 0145:             if a == b:
# 0146:                 OS.append(a)
# 0147:             else:
# 0148:                 OS.append(b)
# 0149:
# 0150:         elif CS[IP] == 'PRN':
# 0151:             result = OS.pop()
# 0152:             print(result)
# 0153:             IP += 0
# 0154:
# 0155:         elif CS[IP] == 'PRB':
# 0156:
# 0157:             result = OS.pop()
# 0158:             if result == 0 or result == 0.0:
# 0159:                 print('false')
# 0160:             else:
# 0161:                 print('true')
# 0162:             IP += 0
# 0163:
# 0164:         elif CS[IP] == 'STR':
# 0165:
# 0166:             print(LP[r][1:-1], end = '')
# 0167:             IP += 0
# 0168:
# 0169:         elif CS[IP] == 'XCHG':
# 0170:
# 0171:             temp = OS[-2]
# 0172:             OS[-2] = OS[-1]
# 0173:             OS[-1] = temp
# 0174:
# 0175:         # ---------------------------------------------------------------------
# 0176:         #
# 0177:         # saltos / subrutinas
# 0178:         #
# 0179:         elif CS[IP] == 'LBL':
# 0180:
# 0181:             IP += 1
# 0182:
# 0183:         elif CS[IP] == 'GTO':
# 0184:
# 0185:             IP = JT[r] - 1
# 0186:
# 0187:         elif CS[IP] == 'IFZ':
# 0188:
# 0189:             IP = JT[r] - 1 if OS.pop() == 0 else IP + 1
# 0190:
# 0191:         elif CS[IP] == 'IFNZ':
# 0192:
# 0193:             IP = JT[r] - 1 if OS.pop() != 0 else IP + 1
# 0194:
# 0195:         elif CS[IP] == 'GSB':
# 0196:
# 0197:             SF.append(IP + 1)
# 0198:             IP = JT[r] - 1
# 0199:
# 0200:         elif CS[IP] == 'RET':
# 0201:
# 0202:             IP = SF.pop()
# 0203:
# 0204:         # ---------------------------------------------------------------------
# 0205:         #
# 0206:         # gestion de la memoria
# 0207:         #
# 0208:         elif CS[IP] == 'RCL':
# 0209:
# 0210:                 OS.append( DR[r] )
# 0211:                 IP += 1
# 0212:
# 0213:         elif CS[IP] == 'RCL+':
# 0214:
# 0215:                 OS[-1] += DR[s]
# 0216:                 IP += 2
# 0217:
# 0218:         elif CS[IP] == 'RCL*':
# 0219:
# 0220:                 OS[-1] *= DR[s]
# 0221:                 IP += 2
# 0222:
# 0223:         elif CS[IP] == 'RCL-':
# 0224:
# 0225:                 OS[-1] -= DR[s]
# 0226:                 IP += 2
# 0227:
# 0228:         elif CS[IP] == 'RCL/':
# 0229:
# 0230:                 OS[-1] /= DR[s]
# 0231:                 IP += 2
# 0232:
# 0233:         elif CS[IP] == 'STO':
# 0234:
# 0235:                 DR[r] = OS.pop()
# 0236:                 IP += 1
# 0237:
# 0238:         elif CS[IP] == 'STO+':
# 0239:
# 0240:                 DR[r] += OS.pop()
# 0241:                 IP += 1
# 0242:
# 0243:         elif CS[IP] == 'STO*':
# 0244:
# 0245:                 DR[r] *= OS.pop()
# 0246:                 IP += 1
# 0247:
# 0248:         elif CS[IP] == 'STO-':
# 0249:
# 0250:                 DR[r] -= OS.pop()
# 0251:                 IP += 1
# 0252:
# 0253:         elif CS[IP] == 'STO/':
# 0254:
# 0255:                 DR[r] /= OS.pop()
# 0256:                 IP += 1
# 0257:
# 0258:         elif CS[IP] == 'STO%':
# 0259:
# 0260:                 DR[r] %= OS.pop()
# 0261:                 IP += 1
# 0262:
# 0263:         elif CS[IP] == 'STO++':
# 0264:
# 0265:                 DR[r] += 1
# 0266:                 IP += 1
# 0267:
# 0268:         elif CS[IP] == 'STO--':
# 0269:
# 0270:                 DR[r] -= 1
# 0271:                 IP += 1
# 0272:
# 0273:         # ---------------------------------------------------------------------
# 0274:         #
# 0275:         # funciones matematicas (math library)
# 0276:         #
# 0277:         elif CS[IP] == 'FABS':
# 0278:
# 0279:             OS[-1] = math.fabs(OS[-1])
# 0280:
# 0281:         elif CS[IP] == 'SQRT':
# 0282:
# 0283:              OS[-1] = math.sqrt(OS[-1])
# 0284:
# 0285:         elif CS[IP] == 'LOG':
# 0286:
# 0287:             OS[-1] = math.log(OS[-1])
# 0288:
# 0289:         elif CS[IP] == 'EXP':
# 0290:
# 0291:             OS[-1] = math.exp(OS[-1])
# 0292:
# 0293:         elif CS[IP] == 'LOG10':
# 0294:
# 0295:             OS[-1] = math.log10(OS[-1])
# 0296:
# 0297:         elif CS[IP] == 'SIN':
# 0298:
# 0299:             OS[-1] = math.sin(OS[-1])
# 0300:
# 0301:         elif CS[IP] == 'COS':
# 0302:
# 0303:             OS[-1] = math.cos(OS[-1])
# 0304:
# 0305:         elif CS[IP] == 'TAN':
# 0306:
# 0307:             OS[-1] = math.tan(OS[-1])
# 0308:
# 0309:         elif CS[IP] == 'ASN':
# 0310:
# 0311:             OS[-1] = math.asin(OS[-1])
# 0312:
# 0313:         elif CS[IP] == 'ACS':
# 0314:
# 0315:             OS[-1] = math.acos(OS[-1])
# 0316:
# 0317:         elif CS[IP] == 'ATN':
# 0318:
# 0319:             OS[-1] = math.atan(OS[-1])
# 0320:         #
# 0321:         # funciones compelentarias
# 0322:         #
# 0323:         elif CS[IP] == 'CHS':
# 0324:
# 0325:             OS[-1]  = - OS[-1]
# 0326:
# 0327:         elif CS[IP] == 'SQ':
# 0328:
# 0329:             OS[-1]  = OS[-1] ^  2
# 0330:
# 0331:         elif CS[IP] == 'INV':
# 0332:
# 0333:             OS[-1]  = 1 / OS[-1]
# 0334:
# 0335:         elif CS[IP] == 'INTG':
# 0336:
# 0337:             OS[-1]  = int(OS[-1])
# 0338:
# 0339:         elif CS[IP] == 'FRAC':
# 0340:
# 0341:             OS[-1]  = OS[-1] - int(OS[-1])
# 0342:
# 0343:         elif CS[IP] == 'INCR':
# 0344:
# 0345:             OS[-1]  += 1
# 0346:
# 0347:         elif CS[IP] == 'DECR':
# 0348:
# 0349:             OS[-1]  -= 1
# 0350:
# 0351:         # ---------------------------------------------------------------------
# 0352:         elif CS[IP] == '+':
# 0353:
# 0354:             OS.append(OS.pop() + OS.pop())
# 0355:
# 0356:         elif CS[IP] == '*':
# 0357:
# 0358:             OS.append(OS.pop() * OS.pop())
# 0359:
# 0360:         elif CS[IP] == '-':
# 0361:
# 0362:             OS.append(- OS.pop() + OS.pop())
# 0363:
# 0364:         elif CS[IP] == '/':
# 0365:
# 0366:             OS.append(1 / OS.pop() * OS.pop())
# 0367:
# 0368:         elif CS[IP] == '%':
# 0369:
# 0370:             b = OS.pop()
# 0371:             a = OS.pop()
# 0372:             OS.append(b % a)
# 0373:
# 0374:         # ---------------------------------------------------------------------
# 0375:         elif CS[IP] == '==':
# 0376:
# 0377:             OS.append(1 if OS.pop() == OS.pop() else 0)
# 0378:
# 0379:         elif CS[IP] == '<':
# 0380:
# 0381:             OS.append(1 if OS.pop() > OS.pop() else 0)
# 0382:
# 0383:         elif CS[IP] == '<=':
# 0384:
# 0385:             OS.append(1 if OS.pop() >= OS.pop() else 0)
# 0386:
# 0387:         elif CS[IP] == '>':
# 0388:
# 0389:             OS.append(1 if OS.pop() < OS.pop() else 0)
# 0390:
# 0391:         elif CS[IP] == '>=':
# 0392:
# 0393:             OS.append(1 if OS.pop() <= OS.pop() else 0)
# 0394:
# 0395:         elif CS[IP] == '==':
# 0396:
# 0397:             OS.append(1 if OS.pop() == OS.pop() else 0)
# 0398:
# 0399:         elif CS[IP] == '!=':
# 0400:
# 0401:             OS.append(1 if OS.pop() != OS.pop() else 0)
# 0402:
# 0403:         elif CS[IP] == 'AND':
# 0404:
# 0405:             OS.append(1 if OS.pop() and OS.pop() else 0)
# 0406:
# 0407:         elif CS[IP] == 'OR':
# 0408:
# 0409:             OS.append(1 if OS.pop() or OS.pop() else 0)
# 0410:
# 0411:         elif CS[IP] == 'NOT':
# 0412:
# 0413:             OS[-1] = 1 if OS[-1] == 0 else 0
# 0414:
# 0415:         else:
# 0416:
# 0417:             txt = '\n\nsbm Syntax error: unknown bytecode <{}>\n\n'.format(CS[IP])
# 0418:             print(txt)
# 0419:             sys.exit()
# 0420:
# 0421:         # ---------------------------------------------------------------------
# 0422:
# 0423:         IP += 1
# 0424:
# 0425:
# 0426:
# 0427: #
# 0428: # Esa es la rutina principal para llamada de la funcion
# 0429: # La variable DBG controla si se ejecutan las corridas
# 0430: # de diagnostico o la operacion normal del programa
# 0431: #
# 0432:
# 0433: if __name__ == '__main__':
# 0434:
# 0435:
# 0436:     if len(sys.argv) > 1:
# 0437:         for filename in sys.argv[1:]:
# 0438:             sbm(filename)
# 0439:     else:
# 0440:         filename = input()
# 0441:         sbm(filename)
# 0442:

# %% [markdown]
# ---

# %% [markdown]
# [Contenido](#Contenido)
